# %%
import pandas as pd
import numpy as np

import plotly.graph_objects as go
import plotly.express as px


from dash import Dash, dcc, html
from dash import html

from dash.dependencies import Output, Input
from dash.exceptions import PreventUpdate

education = pd.read_csv("../Data/states_all.csv").assign(
    expenditure_per_student = lambda x: x["TOTAL_EXPENDITURE"] / x["GRADES_ALL_G"],
    above_avg_math8 = lambda x: np.where(x["AVG_MATH_8_SCORE"] > 278.6,'Above Avg', 'Below Avg')
)

education.tail()
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 1710              NaN            NaN            NaN                NaN
# 1711              NaN            NaN            NaN                NaN
# 1712              NaN            NaN            NaN                NaN
# 1713              NaN            NaN            NaN                NaN
# 1714              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  ...  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# 1710                      NaN  ...          NaN           NaN            NaN
# 1711                      NaN  ...          NaN           NaN            NaN
# 1712                      NaN  ...          NaN           NaN            NaN
# 1713                      NaN  ...          NaN           NaN            NaN
# 1714                      NaN  ...          NaN           NaN            NaN
#
#       GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 1710           NaN             247.0             287.0                224.0
# 1711           NaN             240.0             286.0                220.0
# 1712           NaN             231.0             272.0                213.0
# 1713           NaN             242.0             289.0                220.0
# 1714           NaN             246.0             286.0                227.0
#
#       AVG_READING_8_SCORE  expenditure_per_student  above_avg_math8
# 1710                262.0                      NaN        Above Avg
# 1711                266.0                      NaN        Above Avg
# 1712                256.0                      NaN        Below Avg
# 1713                267.0                      NaN        Above Avg
# 1714                265.0                      NaN        Above Avg
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Labels & Values

# %%
dcc.Dropdown(
        id="X Column Picker",
        options=dict(zip(
            education.select_dtypes(include='number').columns,
            [column.title() for column in education.select_dtypes(include='number').columns],
        )),
        value="expenditure_per_student",
),
# Out:
# (Dropdown(options={'YEAR': 'Year', 'ENROLL': 'Enroll', 'TOTAL_REVENUE': 'Total_Revenue', 'FEDERAL_REVENUE': 'Federal_Revenue', 'STATE_REVENUE': 'State_Revenue', 'LOCAL_REVENUE': 'Local_Revenue', 'TOTAL_EXPENDITURE': 'Total_Expenditure', 'INSTRUCTION_EXPENDITURE': 'Instruction_Expenditure', 'SUPPORT_SERVICES_EXPENDITURE': 'Support_Services_Expenditure', 'OTHER_EXPENDITURE': 'Other_Expenditure', 'CAPITAL_OUTLAY_EXPENDITURE': 'Capital_Outlay_Expenditure', 'GRADES_PK_G': 'Grades_Pk_G', 'GRADES_KG_G': 'Grades_Kg_G', 'GRADES_4_G': 'Grades_4_G', 'GRADES_8_G': 'Grades_8_G', 'GRADES_12_G': 'Grades_12_G', 'GRADES_1_8_G': 'Grades_1_8_G', 'GRADES_9_12_G': 'Grades_9_12_G', 'GRADES_ALL_G': 'Grades_All_G', 'AVG_MATH_4_SCORE': 'Avg_Math_4_Score', 'AVG_MATH_8_SCORE': 'Avg_Math_8_Score', 'AVG_READING_4_SCORE': 'Avg_Reading_4_Score', 'AVG_READING_8_SCORE': 'Avg_Reading_8_Score', 'expenditure_per_student': 'Expenditure_Per_Student'}, value='expenditure_per_student', id='X Column Picker'),)

# %%
app = Dash(__name__)

app.layout = html.Div([
    html.H2(id="header"),
    dcc.Dropdown(
        id="X Column Picker",
        options=list(education.select_dtypes(include='number').columns),
        value="TOTAL_EXPENDITURE"
),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output("header", "children"),
    Output("graph", "figure"),
    Input("X Column Picker", "value")
)

def plot_rev_scatter(x):
    if not x:
        raise PreventUpdate
    fig = px.scatter(
        education, 
        x=x, 
        y="AVG_MATH_8_SCORE",
        trendline="ols",
    )
    header = f"Math Score vs {x.title()}"
    return header, fig

if __name__ == "__main__":
    app.run(mode="inline", port=9271, debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:9271/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Multi Select Dropdowns

# %%
test = "HELLO"
test.title()
# Out:
# 'Hello'

# %%
app = Dash(__name__)

app.layout = html.Div([
   dcc.Dropdown(
        id="filter",
        # options=education["STATE"].unique(),
        options=[{"label": state.title(), "value": state} for state in education["STATE"].unique()],
        value=["CALIFORNIA", "OREGON"],
        multi=True # pass multiple values into callback
    ),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output('graph', 'figure'),
    Input("filter", "value"),
)

def plot_rev_scatter(state):
    fig = px.line(
        (education
         .query("STATE in @state and 1992 < YEAR < 2016")
         .reset_index()
        ), 
        x="YEAR", 
        y="TOTAL_EXPENDITURE",
        color="STATE",
        title = f"Expenditure Over Time, Selected States",
    ) 
    return fig


if __name__ == "__main__":
    app.run(mode="inline", port=2023, debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2023/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
app = Dash(__name__)

app.layout= html.Div([
    dcc.Dropdown(
        id="filter",
        #styling the filter texts
        options=[{
            "label": html.Span(["Serene Republic of California"], style={"color": "powderblue", "font-size": 24}),
            "value":"CALIFORNIA"
        },
        {
            "label": html.Span(["Texas Zone of Anarchy"], style={"color": "brown", "font-size": 16}),
            "value": "TEXAS"
            
        }],
        value=["CALIFORNIA"],
        multi=True
    ),
    dcc.Graph(id="graph")
])
    
@app.callback(
    Output("graph", "figure"),
    Input("filter", "value")
)

def exp_line_chart(state):
    fig = px.line(
        (education
         .query("State in @state and 1992 < YEAR < 2016")
         .groupby(["YEAR", "STATE"])
         .sum()
         .reset_index()
        ),
        x="YEAR",
        y="TOTAL_EXPENDITURE",
        color="STATE",
        title = f"Expenditure Over Time, Selected States",
    )
    return fig

if __name__ == "__main__":
    app.run(mode="inline", debug=True, port=1234)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:1234/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Checklists

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.Checklist(
        id="scores",
        options=[
            "AVG_MATH_4_SCORE",
            "AVG_MATH_8_SCORE",
            "AVG_READING_4_SCORE",
            "AVG_READING_8_SCORE"
        ],
        value=["AVG_MATH_4_SCORE"]
    ),
    dcc.Graph(id="graph")    
])

@app.callback(
    Output("graph", "figure"),
    Input("scores", "value")
)

def plot_hist(scores):
    fig = px.histogram(
        education,
        x=scores,
        barmode="overlay",
        title="Score Distribution"
    ).update_traces(opacity=.6)
    
    return fig

app.run(mode="inline", port=2084)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2084/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.Checklist(
        id="filter",
        options = ["CALIFORNIA", "TEXAS", "FLORIDA", "OREGON"],
#         options= [{"label": state.title(), "value": state} for state in education["STATE"].unique()] #note this is too many options, drop down may
        value=["CALIFORNIA", "TEXAS"]
    ),
    dcc.Graph(id="graph")    
])



@app.callback(
    Output("graph", "figure"),
    Input("filter", "value")
)


def exp_by_state(state):
    fig = px.line(
        (education
         .query("STATE in @state and 1992 < YEAR < 2016 ")
         .groupby(["YEAR", "STATE"])
         .sum()
         .reset_index()
        ),
        x="YEAR",
        y="TOTAL_EXPENDITURE",
        color="STATE",
        title="Expenditure Over Time, Selected States"
    )

    return fig

if __name__ == "__main__":
    app.run(mode="inline", port=4829)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:4829/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### RadioItems (example of multiple filters)

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.RadioItems(
        id="OLS Toggle",
        options=["Trendline On", "Trendline Off"],
        value="Trendline Off"
    ),
    dcc.Checklist(
        id="scores",
        options=[
            "AVG_MATH_4_SCORE",
            "AVG_MATH_8_SCORE",
            "AVG_READING_4_SCORE",
            "AVG_READING_8_SCORE"
        ],
        value=["AVG_MATH_4_SCORE"]
    ),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output('graph', 'figure'),
    Input("OLS Toggle", "value"),
    Input("scores", "value")
)

def plot_rev_scatter(ols, scores):
    fig = px.scatter(
        education, 
        x="expenditure_per_student", 
        y=scores,
        trendline=None if ols == "Trendline Off" else "ols", # conditional logic
        title = "The Relationship Between Spending and Test Scores",
        )
    return fig

if __name__ == "__main__":
    app.run(mode="inline", debug=True, port=8274)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/scope.py:233, in Scope.resolve(
#     self=Scope(scope=['Timestamp',
#  'datetime',
#  'True',
# ... 'expenditure_per_student',
#  'above_avg_math8']
# ),
#     key='State',
#     is_local=False
# )
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#         self = Scope(scope=['Timestamp',
#  'datetime',
#  'True',
#  'False',
#  'list',
#  'tuple',
#  'inf',
#  'Inf',
#  '__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  'pd',
#  'np',
#  'go',
#  'px',
#  'Dash',
#  'dcc',
#  'html',
#  'Output',
#  'Input',
#  'PreventUpdate',
#  'education',
#  '_1',
#  '_i2',
#  '_2',
#  '_i3',
#  'app',
#  'plot_rev_scatter',
#  '_i4',
#  'test',
#  '_4',
#  '_i5',
#  '_i6',
#  'exp_line_chart',
#  'state']
# , resolvers=['ilevel_0',
#  'index',
#  'clevel_0',
#  'columns',
#  'PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE',
#  'expenditure_per_student',
#  'above_avg_math8']
# )
#         self.resolvers = DeepChainMap({'PRIMARY_KEY': 0             1992_ALABAMA
# 1              1992_ALASKA
# 2             1992_ARIZONA
# 3            1992_ARKANSAS
# 4          1992_CALIFORNIA
#                ...
# 1710         2019_VIRGINIA
# 1711       2019_WASHINGTON
# 1712    2019_WEST_VIRGINIA
# 1713        2019_WISCONSIN
# 1714          2019_WYOMING
# Name: PRIMARY_KEY, Length: 1715, dtype: object, 'STATE': 0             ALABAMA
# 1              ALASKA
# 2             ARIZONA
# 3            ARKANSAS
# 4          CALIFORNIA
#             ...
# 1710         VIRGINIA
# 1711       WASHINGTON
# 1712    WEST_VIRGINIA
# 1713        WISCONSIN
# 1714          WYOMING
# Name: STATE, Length: 1715, dtype: object, 'YEAR': 0       1992
# 1       1992
# 2       1992
# 3       1992
# 4       1992
#         ...
# 1710    2019
# 1711    2019
# 1712    2019
# 1713    2019
# 1714    2019
# Name: YEAR, Length: 1715, dtype: int64, 'ENROLL': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: ENROLL, Length: 1715, dtype: float64, 'TOTAL_REVENUE': 0        2678885.0
# 1        1049591.0
# 2        3258079.0
# 3        1711959.0
# 4       26260025.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_REVENUE, Length: 1715, dtype: float64, 'FEDERAL_REVENUE': 0        304177.0
# 1        106780.0
# 2        297888.0
# 3        178571.0
# 4       2072470.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: FEDERAL_REVENUE, Length: 1715, dtype: float64, 'STATE_REVENUE': 0        1659028.0
# 1         720711.0
# 2        1369815.0
# 3         958785.0
# 4       16546514.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: STATE_REVENUE, Length: 1715, dtype: float64, 'LOCAL_REVENUE': 0        715680.0
# 1        222100.0
# 2       1590376.0
# 3        574603.0
# 4       7641041.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: LOCAL_REVENUE, Length: 1715, dtype: float64, 'TOTAL_EXPENDITURE': 0        2653798.0
# 1         972488.0
# 2        3401580.0
# 3        1743022.0
# 4       27138832.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_EXPENDITURE, Length: 1715, dtype: float64, 'INSTRUCTION_EXPENDITURE': 0        1481703.0
# 1         498362.0
# 2        1435908.0
# 3         964323.0
# 4       14358922.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: INSTRUCTION_EXPENDITURE, Length: 1715, dtype: float64, 'SUPPORT_SERVICES_EXPENDITURE': 0        735036.0
# 1        350902.0
# 2       1007732.0
# 3        483488.0
# 4       8520926.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: SUPPORT_SERVICES_EXPENDITURE, Length: 1715, dtype: float64, 'OTHER_EXPENDITURE': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: OTHER_EXPENDITURE, Length: 1715, dtype: float64, 'CAPITAL_OUTLAY_EXPENDITURE': 0        174053.0
# 1         37451.0
# 2        609114.0
# 3        145212.0
# 4       2044688.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: CAPITAL_OUTLAY_EXPENDITURE, Length: 1715, dtype: float64, 'GRADES_PK_G': 0        8224.0
# 1        2371.0
# 2        2544.0
# 3         808.0
# 4       59067.0
#          ...
# 1710        NaN
# 1711        NaN
# 1712        NaN
# 1713        NaN
# 1714        NaN
# Name: GRADES_PK_G, Length: 1715, dtype: float64, 'GRADES_KG_G': 0        55460.0
# 1        10152.0
# 2        53497.0
# 3        33511.0
# 4       431763.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_KG_G, Length: 1715, dtype: float64, 'GRADES_4_G': 0        57948.0
# 1         9748.0
# 2        55433.0
# 3        34632.0
# 4       418418.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_4_G, Length: 1715, dtype: float64, 'GRADES_8_G': 0        58025.0
# 1         8789.0
# 2        49081.0
# 3        36011.0
# 4       363296.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_8_G, Length: 1715, dtype: float64, 'GRADES_12_G': 0        41167.0
# 1         6714.0
# 2        37410.0
# 3        27651.0
# 4       270675.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_12_G, Length: 1715, dtype: float64, 'GRADES_1_8_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_1_8_G, Length: 1715, dtype: float64, 'GRADES_9_12_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_9_12_G, Length: 1715, dtype: float64, 'GRADES_ALL_G': 0        731634.0
# 1        122487.0
# 2        673477.0
# 3        441490.0
# 4       5254844.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: GRADES_ALL_G, Length: 1715, dtype: float64, 'AVG_MATH_4_SCORE': 0       208.0
# 1         NaN
# 2       215.0
# 3       210.0
# 4       208.0
#         ...
# 1710    247.0
# 1711    240.0
# 1712    231.0
# 1713    242.0
# 1714    246.0
# Name: AVG_MATH_4_SCORE, Length: 1715, dtype: float64, 'AVG_MATH_8_SCORE': 0       252.0
# 1         NaN
# 2       265.0
# 3       256.0
# 4       261.0
#         ...
# 1710    287.0
# 1711    286.0
# 1712    272.0
# 1713    289.0
# 1714    286.0
# Name: AVG_MATH_8_SCORE, Length: 1715, dtype: float64, 'AVG_READING_4_SCORE': 0       207.0
# 1         NaN
# 2       209.0
# 3       211.0
# 4       202.0
#         ...
# 1710    224.0
# 1711    220.0
# 1712    213.0
# 1713    220.0
# 1714    227.0
# Name: AVG_READING_4_SCORE, Length: 1715, dtype: float64, 'AVG_READING_8_SCORE': 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1710    262.0
# 1711    266.0
# 1712    256.0
# 1713    267.0
# 1714    265.0
# Name: AVG_READING_8_SCORE, Length: 1715, dtype: float64, 'expenditure_per_student': 0       3.627221
# 1       7.939520
# 2       5.050774
# 3       3.948044
# 4       5.164536
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: expenditure_per_student, Length: 1715, dtype: float64, 'above_avg_math8': 0       Below Avg
# 1       Below Avg
# 2       Below Avg
# 3       Below Avg
# 4       Below Avg
#           ...
# 1710    Above Avg
# 1711    Above Avg
# 1712    Below Avg
# 1713    Above Avg
# 1714    Above Avg
# Name: above_avg_math8, Length: 1715, dtype: object}, {'ilevel_0': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'index': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'clevel_0': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE        CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G                                      GRADES_PK_G
# GRADES_KG_G                                      GRADES_KG_G
# GRADES_4_G                                        GRADES_4_G
# GRADES_8_G                                        GRADES_8_G
# GRADES_12_G                                      GRADES_12_G
# GRADES_1_8_G                                    GRADES_1_8_G
# GRADES_9_12_G                                  GRADES_9_12_G
# GRADES_ALL_G                                    GRADES_ALL_G
# AVG_MATH_4_SCORE                            AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE                            AVG_MATH_8_SCORE
# AVG_READING_4_SCORE                      AVG_READING_4_SCORE
# AVG_READING_8_SCORE                      AVG_READING_8_SCORE
# expenditure_per_student              expenditure_per_student
# above_avg_math8                              above_avg_math8
# dtype: object, 'columns': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE        CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G                                      GRADES_PK_G
# GRADES_KG_G                                      GRADES_KG_G
# GRADES_4_G                                        GRADES_4_G
# GRADES_8_G                                        GRADES_8_G
# GRADES_12_G                                      GRADES_12_G
# GRADES_1_8_G                                    GRADES_1_8_G
# GRADES_9_12_G                                  GRADES_9_12_G
# GRADES_ALL_G                                    GRADES_ALL_G
# AVG_MATH_4_SCORE                            AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE                            AVG_MATH_8_SCORE
# AVG_READING_4_SCORE                      AVG_READING_4_SCORE
# AVG_READING_8_SCORE                      AVG_READING_8_SCORE
# expenditure_per_student              expenditure_per_student
# above_avg_math8                              above_avg_math8
# dtype: object})
#         key = 'State'
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File ~/opt/anaconda3/lib/python3.8/collections/__init__.py:898, in ChainMap.__getitem__(
#     self=DeepChainMap({'PRIMARY_KEY': 0             1992_...                  above_avg_math8
# dtype: object}),
#     key='State'
# )
#     897         pass
# --> 898 return self.__missing__(key)            # support subclasses that define __missing__
#         self = DeepChainMap({'PRIMARY_KEY': 0             1992_ALABAMA
# 1              1992_ALASKA
# 2             1992_ARIZONA
# 3            1992_ARKANSAS
# 4          1992_CALIFORNIA
#                ...
# 1710         2019_VIRGINIA
# 1711       2019_WASHINGTON
# 1712    2019_WEST_VIRGINIA
# 1713        2019_WISCONSIN
# 1714          2019_WYOMING
# Name: PRIMARY_KEY, Length: 1715, dtype: object, 'STATE': 0             ALABAMA
# 1              ALASKA
# 2             ARIZONA
# 3            ARKANSAS
# 4          CALIFORNIA
#             ...
# 1710         VIRGINIA
# 1711       WASHINGTON
# 1712    WEST_VIRGINIA
# 1713        WISCONSIN
# 1714          WYOMING
# Name: STATE, Length: 1715, dtype: object, 'YEAR': 0       1992
# 1       1992
# 2       1992
# 3       1992
# 4       1992
#         ...
# 1710    2019
# 1711    2019
# 1712    2019
# 1713    2019
# 1714    2019
# Name: YEAR, Length: 1715, dtype: int64, 'ENROLL': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: ENROLL, Length: 1715, dtype: float64, 'TOTAL_REVENUE': 0        2678885.0
# 1        1049591.0
# 2        3258079.0
# 3        1711959.0
# 4       26260025.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_REVENUE, Length: 1715, dtype: float64, 'FEDERAL_REVENUE': 0        304177.0
# 1        106780.0
# 2        297888.0
# 3        178571.0
# 4       2072470.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: FEDERAL_REVENUE, Length: 1715, dtype: float64, 'STATE_REVENUE': 0        1659028.0
# 1         720711.0
# 2        1369815.0
# 3         958785.0
# 4       16546514.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: STATE_REVENUE, Length: 1715, dtype: float64, 'LOCAL_REVENUE': 0        715680.0
# 1        222100.0
# 2       1590376.0
# 3        574603.0
# 4       7641041.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: LOCAL_REVENUE, Length: 1715, dtype: float64, 'TOTAL_EXPENDITURE': 0        2653798.0
# 1         972488.0
# 2        3401580.0
# 3        1743022.0
# 4       27138832.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_EXPENDITURE, Length: 1715, dtype: float64, 'INSTRUCTION_EXPENDITURE': 0        1481703.0
# 1         498362.0
# 2        1435908.0
# 3         964323.0
# 4       14358922.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: INSTRUCTION_EXPENDITURE, Length: 1715, dtype: float64, 'SUPPORT_SERVICES_EXPENDITURE': 0        735036.0
# 1        350902.0
# 2       1007732.0
# 3        483488.0
# 4       8520926.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: SUPPORT_SERVICES_EXPENDITURE, Length: 1715, dtype: float64, 'OTHER_EXPENDITURE': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: OTHER_EXPENDITURE, Length: 1715, dtype: float64, 'CAPITAL_OUTLAY_EXPENDITURE': 0        174053.0
# 1         37451.0
# 2        609114.0
# 3        145212.0
# 4       2044688.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: CAPITAL_OUTLAY_EXPENDITURE, Length: 1715, dtype: float64, 'GRADES_PK_G': 0        8224.0
# 1        2371.0
# 2        2544.0
# 3         808.0
# 4       59067.0
#          ...
# 1710        NaN
# 1711        NaN
# 1712        NaN
# 1713        NaN
# 1714        NaN
# Name: GRADES_PK_G, Length: 1715, dtype: float64, 'GRADES_KG_G': 0        55460.0
# 1        10152.0
# 2        53497.0
# 3        33511.0
# 4       431763.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_KG_G, Length: 1715, dtype: float64, 'GRADES_4_G': 0        57948.0
# 1         9748.0
# 2        55433.0
# 3        34632.0
# 4       418418.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_4_G, Length: 1715, dtype: float64, 'GRADES_8_G': 0        58025.0
# 1         8789.0
# 2        49081.0
# 3        36011.0
# 4       363296.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_8_G, Length: 1715, dtype: float64, 'GRADES_12_G': 0        41167.0
# 1         6714.0
# 2        37410.0
# 3        27651.0
# 4       270675.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_12_G, Length: 1715, dtype: float64, 'GRADES_1_8_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_1_8_G, Length: 1715, dtype: float64, 'GRADES_9_12_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_9_12_G, Length: 1715, dtype: float64, 'GRADES_ALL_G': 0        731634.0
# 1        122487.0
# 2        673477.0
# 3        441490.0
# 4       5254844.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: GRADES_ALL_G, Length: 1715, dtype: float64, 'AVG_MATH_4_SCORE': 0       208.0
# 1         NaN
# 2       215.0
# 3       210.0
# 4       208.0
#         ...
# 1710    247.0
# 1711    240.0
# 1712    231.0
# 1713    242.0
# 1714    246.0
# Name: AVG_MATH_4_SCORE, Length: 1715, dtype: float64, 'AVG_MATH_8_SCORE': 0       252.0
# 1         NaN
# 2       265.0
# 3       256.0
# 4       261.0
#         ...
# 1710    287.0
# 1711    286.0
# 1712    272.0
# 1713    289.0
# 1714    286.0
# Name: AVG_MATH_8_SCORE, Length: 1715, dtype: float64, 'AVG_READING_4_SCORE': 0       207.0
# 1         NaN
# 2       209.0
# 3       211.0
# 4       202.0
#         ...
# 1710    224.0
# 1711    220.0
# 1712    213.0
# 1713    220.0
# 1714    227.0
# Name: AVG_READING_4_SCORE, Length: 1715, dtype: float64, 'AVG_READING_8_SCORE': 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1710    262.0
# 1711    266.0
# 1712    256.0
# 1713    267.0
# 1714    265.0
# Name: AVG_READING_8_SCORE, Length: 1715, dtype: float64, 'expenditure_per_student': 0       3.627221
# 1       7.939520
# 2       5.050774
# 3       3.948044
# 4       5.164536
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: expenditure_per_student, Length: 1715, dtype: float64, 'above_avg_math8': 0       Below Avg
# 1       Below Avg
# 2       Below Avg
# 3       Below Avg
# 4       Below Avg
#           ...
# 1710    Above Avg
# 1711    Above Avg
# 1712    Below Avg
# 1713    Above Avg
# 1714    Above Avg
# Name: above_avg_math8, Length: 1715, dtype: object}, {'ilevel_0': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'index': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'clevel_0': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE        CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G                                      GRADES_PK_G
# GRADES_KG_G                                      GRADES_KG_G
# GRADES_4_G                                        GRADES_4_G
# GRADES_8_G                                        GRADES_8_G
# GRADES_12_G                                      GRADES_12_G
# GRADES_1_8_G                                    GRADES_1_8_G
# GRADES_9_12_G                                  GRADES_9_12_G
# GRADES_ALL_G                                    GRADES_ALL_G
# AVG_MATH_4_SCORE                            AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE                            AVG_MATH_8_SCORE
# AVG_READING_4_SCORE                      AVG_READING_4_SCORE
# AVG_READING_8_SCORE                      AVG_READING_8_SCORE
# expenditure_per_student              expenditure_per_student
# above_avg_math8                              above_avg_math8
# dtype: object, 'columns': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE        CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G                                      GRADES_PK_G
# GRADES_KG_G                                      GRADES_KG_G
# GRADES_4_G                                        GRADES_4_G
# GRADES_8_G                                        GRADES_8_G
# GRADES_12_G                                      GRADES_12_G
# GRADES_1_8_G                                    GRADES_1_8_G
# GRADES_9_12_G                                  GRADES_9_12_G
# GRADES_ALL_G                                    GRADES_ALL_G
# AVG_MATH_4_SCORE                            AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE                            AVG_MATH_8_SCORE
# AVG_READING_4_SCORE                      AVG_READING_4_SCORE
# AVG_READING_8_SCORE                      AVG_READING_8_SCORE
# expenditure_per_student              expenditure_per_student
# above_avg_math8                              above_avg_math8
# dtype: object})
#         key = 'State'
#
# File ~/opt/anaconda3/lib/python3.8/collections/__init__.py:890, in ChainMap.__missing__(
#     self=DeepChainMap({'PRIMARY_KEY': 0             1992_...                  above_avg_math8
# dtype: object}),
#     key='State'
# )
#     889 def __missing__(self, key):
# --> 890     raise KeyError(key)
#         key = 'State'
#
# KeyError: 'State'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(
#     self=Scope(scope=['Timestamp',
#  'datetime',
#  'True',
# ... 'expenditure_per_student',
#  'above_avg_math8']
# ),
#     key='State',
#     is_local=False
# )
#     240 try:
#     241     # last ditch effort we look in temporaries
#     242     # these are created when parsing indexing expressions
#     243     # e.g., df[df > 0]
# --> 244     return self.temps[key]
#         self = Scope(scope=['Timestamp',
#  'datetime',
#  'True',
#  'False',
#  'list',
#  'tuple',
#  'inf',
#  'Inf',
#  '__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  'pd',
#  'np',
#  'go',
#  'px',
#  'Dash',
#  'dcc',
#  'html',
#  'Output',
#  'Input',
#  'PreventUpdate',
#  'education',
#  '_1',
#  '_i2',
#  '_2',
#  '_i3',
#  'app',
#  'plot_rev_scatter',
#  '_i4',
#  'test',
#  '_4',
#  '_i5',
#  '_i6',
#  'exp_line_chart',
#  'state']
# , resolvers=['ilevel_0',
#  'index',
#  'clevel_0',
#  'columns',
#  'PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE',
#  'expenditure_per_student',
#  'above_avg_math8']
# )
#         key = 'State'
#         self.temps = {}
#     245 except KeyError as err:
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[6], line 29, in exp_line_chart(state=['CALIFORNIA'])
#      22 @app.callback(
#      23     Output("graph", "figure"),
#      24     Input("filter", "value")
#      25 )
#      26
#      27 def exp_line_chart(state):
#      28     fig = px.line(
# ---> 29         (education
#         px = <module 'plotly.express' from '/Users/danielyang/opt/anaconda3/lib/python3.8/site-packages/plotly/express/__init__.py'>
#         education =              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0            304177.0      1659028.0       715680.0          2653798.0
# 1            106780.0       720711.0       222100.0           972488.0
# 2            297888.0      1369815.0      1590376.0          3401580.0
# 3            178571.0       958785.0       574603.0          1743022.0
# 4           2072470.0     16546514.0      7641041.0         27138832.0
# ...               ...            ...            ...                ...
# 1710              NaN            NaN            NaN                NaN
# 1711              NaN            NaN            NaN                NaN
# 1712              NaN            NaN            NaN                NaN
# 1713              NaN            NaN            NaN                NaN
# 1714              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  ...  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# 0                   1481703.0  ...      41167.0           NaN            NaN
# 1                    498362.0  ...       6714.0           NaN            NaN
# 2                   1435908.0  ...      37410.0           NaN            NaN
# 3                    964323.0  ...      27651.0           NaN            NaN
# 4                  14358922.0  ...     270675.0           NaN            NaN
# ...                       ...  ...          ...           ...            ...
# 1710                      NaN  ...          NaN           NaN            NaN
# 1711                      NaN  ...          NaN           NaN            NaN
# 1712                      NaN  ...          NaN           NaN            NaN
# 1713                      NaN  ...          NaN           NaN            NaN
# 1714                      NaN  ...          NaN           NaN            NaN
#
#       GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 0         731634.0             208.0             252.0                207.0
# 1         122487.0               NaN               NaN                  NaN
# 2         673477.0             215.0             265.0                209.0
# 3         441490.0             210.0             256.0                211.0
# 4        5254844.0             208.0             261.0                202.0
# ...            ...               ...               ...                  ...
# 1710           NaN             247.0             287.0                224.0
# 1711           NaN             240.0             286.0                220.0
# 1712           NaN             231.0             272.0                213.0
# 1713           NaN             242.0             289.0                220.0
# 1714           NaN             246.0             286.0                227.0
#
#       AVG_READING_8_SCORE  expenditure_per_student  above_avg_math8
# 0                     NaN                 3.627221        Below Avg
# 1                     NaN                 7.939520        Below Avg
# 2                     NaN                 5.050774        Below Avg
# 3                     NaN                 3.948044        Below Avg
# 4                     NaN                 5.164536        Below Avg
# ...                   ...                      ...              ...
# 1710                262.0                      NaN        Above Avg
# 1711                266.0                      NaN        Above Avg
# 1712                256.0                      NaN        Below Avg
# 1713                267.0                      NaN        Above Avg
# 1714                265.0                      NaN        Above Avg
#
# [1715 rows x 27 columns]
#      30          .query("State in @state and 1992 < YEAR < 2016")
#      31          .groupby(["YEAR", "STATE"])
#      32          .sum()
#      33          .reset_index()
#      34         ),
#      35         x="YEAR",
#      36         y="TOTAL_EXPENDITURE",
#      37         color="STATE",
#      38         title = f"Expenditure Over Time, Selected States",
#      39     )
#      40     return fig
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4440, in DataFrame.query(
#     self=             PRIMARY_KEY          STATE  YEAR  E... NaN        Above Avg
#
# [1715 rows x 27 columns],
#     expr='State in @state and 1992 < YEAR < 2016',
#     inplace=False,
#     **kwargs={'level': 1, 'target': None}
# )
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#         kwargs = {'level': 1, 'target': None}
#         expr = 'State in @state and 1992 < YEAR < 2016'
#         self =              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0            304177.0      1659028.0       715680.0          2653798.0
# 1            106780.0       720711.0       222100.0           972488.0
# 2            297888.0      1369815.0      1590376.0          3401580.0
# 3            178571.0       958785.0       574603.0          1743022.0
# 4           2072470.0     16546514.0      7641041.0         27138832.0
# ...               ...            ...            ...                ...
# 1710              NaN            NaN            NaN                NaN
# 1711              NaN            NaN            NaN                NaN
# 1712              NaN            NaN            NaN                NaN
# 1713              NaN            NaN            NaN                NaN
# 1714              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  ...  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# 0                   1481703.0  ...      41167.0           NaN            NaN
# 1                    498362.0  ...       6714.0           NaN            NaN
# 2                   1435908.0  ...      37410.0           NaN            NaN
# 3                    964323.0  ...      27651.0           NaN            NaN
# 4                  14358922.0  ...     270675.0           NaN            NaN
# ...                       ...  ...          ...           ...            ...
# 1710                      NaN  ...          NaN           NaN            NaN
# 1711                      NaN  ...          NaN           NaN            NaN
# 1712                      NaN  ...          NaN           NaN            NaN
# 1713                      NaN  ...          NaN           NaN            NaN
# 1714                      NaN  ...          NaN           NaN            NaN
#
#       GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# 0         731634.0             208.0             252.0                207.0
# 1         122487.0               NaN               NaN                  NaN
# 2         673477.0             215.0             265.0                209.0
# 3         441490.0             210.0             256.0                211.0
# 4        5254844.0             208.0             261.0                202.0
# ...            ...               ...               ...                  ...
# 1710           NaN             247.0             287.0                224.0
# 1711           NaN             240.0             286.0                220.0
# 1712           NaN             231.0             272.0                213.0
# 1713           NaN             242.0             289.0                220.0
# 1714           NaN             246.0             286.0                227.0
#
#       AVG_READING_8_SCORE  expenditure_per_student  above_avg_math8
# 0                     NaN                 3.627221        Below Avg
# 1                     NaN                 7.939520        Below Avg
# 2                     NaN                 5.050774        Below Avg
# 3                     NaN                 3.948044        Below Avg
# 4                     NaN                 5.164536        Below Avg
# ...                   ...                      ...              ...
# 1710                262.0                      NaN        Above Avg
# 1711                266.0                      NaN        Above Avg
# 1712                256.0                      NaN        Below Avg
# 1713                267.0                      NaN        Above Avg
# 1714                265.0                      NaN        Above Avg
#
# [1715 rows x 27 columns]
#    4442 try:
#    4443     result = self.loc[res]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4566, in DataFrame.eval(
#     self=             PRIMARY_KEY          STATE  YEAR  E... NaN        Above Avg
#
# [1715 rows x 27 columns],
#     expr='State in @state and 1992 < YEAR < 2016',
#     inplace=False,
#     **kwargs={'level': 2, 'resolvers': ({'AVG_MATH_4_SCORE': 0       208.0
# 1         NaN
# 2       215.0
# 3     ...e: AVG_MATH_4_SCORE, Length: 1715, dtype: float64, 'AVG_MATH_8_SCORE': 0       252.0
# 1         NaN
# 2       265.0
# 3     ...e: AVG_MATH_8_SCORE, Length: 1715, dtype: float64, 'AVG_READING_4_SCORE': 0       207.0
# 1         NaN
# 2       209.0
# 3     ...AVG_READING_4_SCORE, Length: 1715, dtype: float64, 'AVG_READING_8_SCORE': 0         NaN
# 1         NaN
# 2         NaN
# 3     ...AVG_READING_8_SCORE, Length: 1715, dtype: float64, 'CAPITAL_OUTLAY_EXPENDITURE': 0        174053.0
# 1         37451.0
# 2        609..._OUTLAY_EXPENDITURE, Length: 1715, dtype: float64, 'ENROLL': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4   ...   NaN
# Name: ENROLL, Length: 1715, dtype: float64, 'FEDERAL_REVENUE': 0        304177.0
# 1        106780.0
# 2        297...me: FEDERAL_REVENUE, Length: 1715, dtype: float64, 'GRADES_12_G': 0        41167.0
# 1         6714.0
# 2        37410...N
# Name: GRADES_12_G, Length: 1715, dtype: float64, 'GRADES_1_8_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4   ...
# Name: GRADES_1_8_G, Length: 1715, dtype: float64, 'GRADES_4_G': 0        57948.0
# 1         9748.0
# 2        55433...aN
# Name: GRADES_4_G, Length: 1715, dtype: float64, ...}, {'clevel_0': PRIMARY_KEY                                     ...                    above_avg_math8
# dtype: object, 'columns': PRIMARY_KEY                                     ...                    above_avg_math8
# dtype: object, 'ilevel_0': 0          0
# 1          1
# 2          2
# 3        ...3    1713
# 1714    1714
# Length: 1715, dtype: int64, 'index': 0          0
# 1          1
# 2          2
# 3        ...3    1713
# 1714    1714
# Length: 1715, dtype: int64}), 'target': None}
# )
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#         inplace = False
#         kwargs = {'target': None, 'level': 2, 'resolvers': ({'PRIMARY_KEY': 0             1992_ALABAMA
# 1              1992_ALASKA
# 2             1992_ARIZONA
# 3            1992_ARKANSAS
# 4          1992_CALIFORNIA
#                ...
# 1710         2019_VIRGINIA
# 1711       2019_WASHINGTON
# 1712    2019_WEST_VIRGINIA
# 1713        2019_WISCONSIN
# 1714          2019_WYOMING
# Name: PRIMARY_KEY, Length: 1715, dtype: object, 'STATE': 0             ALABAMA
# 1              ALASKA
# 2             ARIZONA
# 3            ARKANSAS
# 4          CALIFORNIA
#             ...
# 1710         VIRGINIA
# 1711       WASHINGTON
# 1712    WEST_VIRGINIA
# 1713        WISCONSIN
# 1714          WYOMING
# Name: STATE, Length: 1715, dtype: object, 'YEAR': 0       1992
# 1       1992
# 2       1992
# 3       1992
# 4       1992
#         ...
# 1710    2019
# 1711    2019
# 1712    2019
# 1713    2019
# 1714    2019
# Name: YEAR, Length: 1715, dtype: int64, 'ENROLL': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: ENROLL, Length: 1715, dtype: float64, 'TOTAL_REVENUE': 0        2678885.0
# 1        1049591.0
# 2        3258079.0
# 3        1711959.0
# 4       26260025.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_REVENUE, Length: 1715, dtype: float64, 'FEDERAL_REVENUE': 0        304177.0
# 1        106780.0
# 2        297888.0
# 3        178571.0
# 4       2072470.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: FEDERAL_REVENUE, Length: 1715, dtype: float64, 'STATE_REVENUE': 0        1659028.0
# 1         720711.0
# 2        1369815.0
# 3         958785.0
# 4       16546514.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: STATE_REVENUE, Length: 1715, dtype: float64, 'LOCAL_REVENUE': 0        715680.0
# 1        222100.0
# 2       1590376.0
# 3        574603.0
# 4       7641041.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: LOCAL_REVENUE, Length: 1715, dtype: float64, 'TOTAL_EXPENDITURE': 0        2653798.0
# 1         972488.0
# 2        3401580.0
# 3        1743022.0
# 4       27138832.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: TOTAL_EXPENDITURE, Length: 1715, dtype: float64, 'INSTRUCTION_EXPENDITURE': 0        1481703.0
# 1         498362.0
# 2        1435908.0
# 3         964323.0
# 4       14358922.0
#            ...
# 1710           NaN
# 1711           NaN
# 1712           NaN
# 1713           NaN
# 1714           NaN
# Name: INSTRUCTION_EXPENDITURE, Length: 1715, dtype: float64, 'SUPPORT_SERVICES_EXPENDITURE': 0        735036.0
# 1        350902.0
# 2       1007732.0
# 3        483488.0
# 4       8520926.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: SUPPORT_SERVICES_EXPENDITURE, Length: 1715, dtype: float64, 'OTHER_EXPENDITURE': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: OTHER_EXPENDITURE, Length: 1715, dtype: float64, 'CAPITAL_OUTLAY_EXPENDITURE': 0        174053.0
# 1         37451.0
# 2        609114.0
# 3        145212.0
# 4       2044688.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: CAPITAL_OUTLAY_EXPENDITURE, Length: 1715, dtype: float64, 'GRADES_PK_G': 0        8224.0
# 1        2371.0
# 2        2544.0
# 3         808.0
# 4       59067.0
#          ...
# 1710        NaN
# 1711        NaN
# 1712        NaN
# 1713        NaN
# 1714        NaN
# Name: GRADES_PK_G, Length: 1715, dtype: float64, 'GRADES_KG_G': 0        55460.0
# 1        10152.0
# 2        53497.0
# 3        33511.0
# 4       431763.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_KG_G, Length: 1715, dtype: float64, 'GRADES_4_G': 0        57948.0
# 1         9748.0
# 2        55433.0
# 3        34632.0
# 4       418418.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_4_G, Length: 1715, dtype: float64, 'GRADES_8_G': 0        58025.0
# 1         8789.0
# 2        49081.0
# 3        36011.0
# 4       363296.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_8_G, Length: 1715, dtype: float64, 'GRADES_12_G': 0        41167.0
# 1         6714.0
# 2        37410.0
# 3        27651.0
# 4       270675.0
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: GRADES_12_G, Length: 1715, dtype: float64, 'GRADES_1_8_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_1_8_G, Length: 1715, dtype: float64, 'GRADES_9_12_G': 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1710   NaN
# 1711   NaN
# 1712   NaN
# 1713   NaN
# 1714   NaN
# Name: GRADES_9_12_G, Length: 1715, dtype: float64, 'GRADES_ALL_G': 0        731634.0
# 1        122487.0
# 2        673477.0
# 3        441490.0
# 4       5254844.0
#           ...
# 1710          NaN
# 1711          NaN
# 1712          NaN
# 1713          NaN
# 1714          NaN
# Name: GRADES_ALL_G, Length: 1715, dtype: float64, 'AVG_MATH_4_SCORE': 0       208.0
# 1         NaN
# 2       215.0
# 3       210.0
# 4       208.0
#         ...
# 1710    247.0
# 1711    240.0
# 1712    231.0
# 1713    242.0
# 1714    246.0
# Name: AVG_MATH_4_SCORE, Length: 1715, dtype: float64, 'AVG_MATH_8_SCORE': 0       252.0
# 1         NaN
# 2       265.0
# 3       256.0
# 4       261.0
#         ...
# 1710    287.0
# 1711    286.0
# 1712    272.0
# 1713    289.0
# 1714    286.0
# Name: AVG_MATH_8_SCORE, Length: 1715, dtype: float64, 'AVG_READING_4_SCORE': 0       207.0
# 1         NaN
# 2       209.0
# 3       211.0
# 4       202.0
#         ...
# 1710    224.0
# 1711    220.0
# 1712    213.0
# 1713    220.0
# 1714    227.0
# Name: AVG_READING_4_SCORE, Length: 1715, dtype: float64, 'AVG_READING_8_SCORE': 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1710    262.0
# 1711    266.0
# 1712    256.0
# 1713    267.0
# 1714    265.0
# Name: AVG_READING_8_SCORE, Length: 1715, dtype: float64, 'expenditure_per_student': 0       3.627221
# 1       7.939520
# 2       5.050774
# 3       3.948044
# 4       5.164536
#           ...
# 1710         NaN
# 1711         NaN
# 1712         NaN
# 1713         NaN
# 1714         NaN
# Name: expenditure_per_student, Length: 1715, dtype: float64, 'above_avg_math8': 0       Below Avg
# 1       Below Avg
# 2       Below Avg
# 3       Below Avg
# 4       Below Avg
#           ...
# 1710    Above Avg
# 1711    Above Avg
# 1712    Below Avg
# 1713    Above Avg
# 1714    Above Avg
# Name: above_avg_math8, Length: 1715, dtype: object}, {'ilevel_0': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'index': 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1710    1710
# 1711    1711
# 1712    1712
# 1713    1713
# 1714    1714
# Length: 1715, dtype: int64, 'clevel_0': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE        CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G                                      GRADES_PK_G
# GRADES_KG_G                                      GRADES_KG_G
# GRADES_4_G                                        GRADES_4_G
# GRADES_8_G                                        GRADES_8_G
# GRADES_12_G                                      GRADES_12_G
# GRADES_1_8_G                                    GRADES_1_8_G
# GRADES_9_12_G                                  GRADES_9_12_G
# GRADES_ALL_G                                    GRADES_ALL_G
# AVG_MATH_4_SCORE                            AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE                            AVG_MATH_8_SCORE
# AVG_READING_4_SCORE                      AVG_READING_4_SCORE
# AVG_READING_8_SCORE                      AVG_READING_8_SCORE
# expenditure_per_student              expenditure_per_student
# above_avg_math8                              above_avg_math8
# dtype: object, 'columns': PRIMARY_KEY                                      PRIMARY_KEY
# STATE                                                  STATE
# YEAR                                                    YEAR
# ENROLL                                                ENROLL
# TOTAL_REVENUE                                  TOTAL_REVENUE
# FEDERAL_REVENUE                              FEDERAL_REVENUE
# STATE_REVENUE                                  STATE_REVENUE
# LOCAL_REVENUE                                  LOCAL_REVENUE
# TOTAL_EXPENDITURE                          TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE              INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE    SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE                          OTHER_EXPENDITURE
# ...
# 1714    1714
# Length: 1715, dtype: int64, 'index': 0          0
# 1          1
# 2          2
# 3        ...3    1713
# 1714    1714
# Length: 1715, dtype: int64}),
#     level=2,
#     target=None,
#     inplace=False
# )
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#         engine = 'numexpr'
#         expr = 'State in @state and 1992 < YEAR < 2016'
#         parser = 'pandas'
#         env = Scope(scope=['Timestamp',
#  'datetime',
#  'True',
#  'False',
#  'list',
#  'tuple',
#  'inf',
#  'Inf',
#  '__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  'pd',
#  'np',
#  'go',
#  'px',
#  'Dash',
#  'dcc',
#  'html',
#  'Output',
#  'Input',
#  'PreventUpdate',
#  'education',
#  '_1',
#  '_i2',
#  '_2',
#  '_i3',
#  'app',
#  'plot_rev_scatter',
#  '_i4',
#  'test',
#  '_4',
#  '_i5',
#  '_i6',
#  'exp_line_chart',
#  'state']
# , resolvers=['ilevel_0',
#  'index',
#  'clevel_0',
#  'columns',
#  'PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE',
#  'expenditure_per_student',
#  'above_avg_math8']
# )
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(
#     self=<class 'pandas.core.computation.expr.Expr'> instance,
#     expr='State in @state and 1992 < YEAR < 2016',
#     engine='numexpr',
#     parser='pandas',
#     env=Scope(scope=['Timestamp',
#  'datetime',
#  'True',
# ... 'expenditure_per_student',
#  'above_avg_math8']
# ),
#     level=0
# )
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#         Exception trying to inspect frame. No more locals available.
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(
#     self=<class 'pandas.core.computation.expr.Expr'> instance
# )
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#         self.expr = 'State in @state and 1992 < YEAR < 2016'
#         self._visitor = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#         Exception trying to inspect frame. No more locals available.
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Module object>,
#     **kwargs={}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_Module of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.Module object at 0x7fda0d26f6a0>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Module object>,
#     **kwargs={}
# )
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#         expr = <_ast.Expr object at 0x7fda0d26f670>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Expr object>,
#     **kwargs={}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_Expr of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.Expr object at 0x7fda0d26f670>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Expr object>,
#     **kwargs={}
# )
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#         node.value = <_ast.BoolOp object at 0x7fda0d26f6d0>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#         node = <_ast.Expr object at 0x7fda0d26f670>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.BoolOp object>,
#     **kwargs={}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_BoolOp of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.BoolOp object at 0x7fda0d26f6d0>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:746, in BaseExprVisitor.visit_BoolOp(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.BoolOp object>,
#     **kwargs={}
# )
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#         operands = [<_ast.Compare object at 0x7fda0d26f730>, <_ast.Compare object at 0x7fda0d26f7f0>]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:739, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(
#     x=<_ast.Compare object>,
#     y=<_ast.Compare object>
# )
#     738 def visitor(x, y):
# --> 739     lhs = self._try_visit_binop(x)
#         x = <_ast.Compare object at 0x7fda0d26f730>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#     740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:735, in BaseExprVisitor._try_visit_binop(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     bop=<_ast.Compare object>
# )
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#         bop = <_ast.Compare object at 0x7fda0d26f730>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Compare object>,
#     **kwargs={}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_Compare of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.Compare object at 0x7fda0d26f730>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Compare object>,
#     **kwargs={}
# )
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#         binop = <_ast.BinOp object at 0x7fda0d26f8b0>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.BinOp object>,
#     **kwargs={}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_BinOp of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.BinOp object at 0x7fda0d26f8b0>
#         kwargs = {}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:535, in BaseExprVisitor.visit_BinOp(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.BinOp object>,
#     **kwargs={}
# )
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#         node = <_ast.BinOp object at 0x7fda0d26f8b0>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:455, in BaseExprVisitor._maybe_transform_eq_ne(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.BinOp object>,
#     left=None,
#     right=None
# )
#     453 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     454     if left is None:
# --> 455         left = self.visit(node.left, side="left")
#         left = None
#         node = <_ast.BinOp object at 0x7fda0d26f8b0>
#         node.left = <_ast.Name object at 0x7fda0d26f790>
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#     456     if right is None:
#     457         right = self.visit(node.right, side="right")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Name object>,
#     **kwargs={'side': 'left'}
# )
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#         visitor = <bound method BaseExprVisitor.visit_Name of <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>>
#         node = <_ast.Name object at 0x7fda0d26f790>
#         kwargs = {'side': 'left'}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py:548, in BaseExprVisitor.visit_Name(
#     self=<pandas.core.computation.expr.PandasExprVisitor object>,
#     node=<_ast.Name object>,
#     **kwargs={'side': 'left'}
# )
#     547 def visit_Name(self, node, **kwargs):
# --> 548     return self.term_type(node.id, self.env, **kwargs)
#         self.term_type = <class 'pandas.core.computation.ops.Term'>
#         node.id = 'State'
#         self.env = Scope(scope=['Timestamp',
#  'datetime',
#  'True',
#  'False',
#  'list',
#  'tuple',
#  'inf',
#  'Inf',
#  '__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  'pd',
#  'np',
#  'go',
#  'px',
#  'Dash',
#  'dcc',
#  'html',
#  'Output',
#  'Input',
#  'PreventUpdate',
#  'education',
#  '_1',
#  '_i2',
#  '_2',
#  '_i3',
#  'app',
#  'plot_rev_scatter',
#  '_i4',
#  'test',
#  '_4',
#  '_i5',
#  '_i6',
#  'exp_line_chart',
#  'state']
# , resolvers=['ilevel_0',
#  'index',
#  'clevel_0',
#  'columns',
#  'PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE',
#  'expenditure_per_student',
#  'above_avg_math8']
# )
#         self = <pandas.core.computation.expr.PandasExprVisitor object at 0x7fda0d26f610>
#         node = <_ast.Name object at 0x7fda0d26f790>
#         kwargs = {'side': 'left'}
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/ops.py:86, in Term.__init__(
#     self=State,
#     name='State',
#     env=Scope(scope=['Timestamp',
#  'datetime',
#  'True',
# ... 'expenditure_per_student',
#  'above_avg_math8']
# ),
#     side='left',
#     encoding=None
# )
#      84 tname = str(name)
#      85 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86 self._value = self._resolve_name()
#         self = State
#      87 self.encoding = encoding
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/ops.py:110, in Term._resolve_name(self=State)
#     105 if local_name in self.env.scope and isinstance(
#     106     self.env.scope[local_name], type
#     107 ):
#     108     is_local = False
# --> 110 res = self.env.resolve(local_name, is_local=is_local)
#         local_name = 'State'
#         is_local = False
#         self = State
#         self.env = Scope(scope=['Timestamp',
#  'datetime',
#  'True',
#  'False',
#  'list',
#  'tuple',
#  'inf',
#  'Inf',
#  '__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  'pd',
#  'np',
#  'go',
#  'px',
#  'Dash',
#  'dcc',
#  'html',
#  'Output',
#  'Input',
#  'PreventUpdate',
#  'education',
#  '_1',
#  '_i2',
#  '_2',
#  '_i3',
#  'app',
#  'plot_rev_scatter',
#  '_i4',
#  'test',
#  '_4',
#  '_i5',
#  '_i6',
#  'exp_line_chart',
#  'state']
# , resolvers=['ilevel_0',
#  'index',
#  'clevel_0',
#  'columns',
#  'PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE',
#  'expenditure_per_student',
#  'above_avg_math8']
# )
#     111 self.update(res)
#     113 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/scope.py:246, in Scope.resolve(
#     self=Scope(scope=['Timestamp',
#  'datetime',
#  'True',
# ... 'expenditure_per_student',
#  'above_avg_math8']
# ),
#     key='State',
#     is_local=False
# )
#     244     return self.temps[key]
#     245 except KeyError as err:
# --> 246     raise UndefinedVariableError(key, is_local) from err
#         is_local = False
#         key = 'State'
#
# UndefinedVariableError: name 'State' is not defined
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8274/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.RadioItems(
        id="aggfunc",
        options=["mean", "sum", "median"],
        value="mean"
    ),
    dcc.Graph(id="graph")
])

@app.callback(
    Output("graph", "figure"),
    Input("aggfunc", "value")
)
def plot_rev_metric(metric):
    fig = px.bar(
        (education
        .query("STATE in ['CALIFORNIA', 'OREGON', 'WASHINGTON', 'IDAHO'] and 1992 < YEAR < 2016")
        .groupby(["STATE"])
        .agg({"TOTAL_EXPENDITURE": metric})
        .reset_index()
        ),
        x="STATE",
        y="TOTAL_EXPENDITURE",
        text_auto=True,
        title = f" {metric.title()} Expenditure By State"
    )
    return fig

if __name__ == "__main__":
    app.run(mode="inline", debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Sliders

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.Slider(id="spend", min=0, max=30, step=5, value=15),
    dcc.Graph(id="graph"),
])

@app.callback(Output('graph', 'figure'), Input("spend", "value"))

def bar_chart(spending):
    fig = px.bar(
        (education
         .query("expenditure_per_student > @spending")
         .groupby("YEAR", as_index=False)
         .count()),
        x="YEAR",
        y="expenditure_per_student",
        title=f"States that spent over ${spending}K per student"      
    )
    fig.update_yaxes(title="COUNT", range=[0, 50])
    fig.update_xaxes(range=[1991, 2017])
    return fig

if __name__ == "__main__":
    app.run(mode="inline", debug=True, port=2323)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2323/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# range movable start and end points on the slider
app = Dash(__name__)

app.layout = html.Div([
    dcc.RangeSlider(id="spend", min=0, max=30, step=5, value=[10, 15]),
    dcc.Graph(id="graph"),
])

@app.callback(Output('graph', 'figure'), Input("spend", "value"))

def bar_chart(spending):
    fig = px.bar(
        (education
         .query("@spending[0] <= expenditure_per_student <= @spending[1]")
         .groupby("YEAR", as_index=False)
         .count()),
        x="YEAR",
        y="expenditure_per_student",
        title=f"States that spent between ${spending[0]}-{spending[1]}K per student"      
    )
    fig.update_yaxes(title="COUNT", range=[0, 50])
    fig.update_xaxes(range=[1991, 2017])
    return fig

if __name__ == "__main__":
    app.run(mode="inline", debug=True, port=2034)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2034/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
app = Dash(__name__)

app.layout = html.Div([
   dcc.RangeSlider(
        id="score_slider",
        min=education.query("YEAR == 2013")["AVG_MATH_8_SCORE"].min(),
        max=education.query("YEAR == 2013")["AVG_MATH_8_SCORE"].max(),
        step=5,
        value=[270, 280]
    ),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output('graph', 'figure'),
    Input("score_slider", "value"),
)

def plot_rev_scatter(score):
    df = (
        education
        .query("YEAR == 2013")
        .assign(
            score_cutoff =  lambda x: np.where(
                x["AVG_MATH_8_SCORE"].between(score[0], score[1]),
                'In Range', 
                'Out of Range'
            )
        )
    )
    fig = px.scatter(
        df,
        x="AVG_MATH_8_SCORE", 
        y="expenditure_per_student",
        color="score_cutoff",
        hover_name="STATE",
        title = f"Score and Expenditure vs. Threshold",
        )
    return fig


if __name__ == "__main__":
    app.run(mode="inline",debug=True, port=2934)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:2934/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Date Pickers

# %%
collisions = (
    pd.read_csv("../Data/NYC_Collisions.csv")
    .astype({"ACCIDENT_DATE": "datetime64[ns]"})
    .loc[:,["ACCIDENT_DATE", "BOROUGH", "COLLISION_ID"]]
    .groupby(["ACCIDENT_DATE", "BOROUGH"], as_index=False)
    .count()
    .rename(columns={
        "COLLISION_ID":"COLLISIONS", 
        "ACCIDENT_DATE":"DATE"})  
)

collisions.head()
# Out:
#         DATE        BOROUGH  COLLISIONS
# 0 2021-01-01          BRONX          28
# 1 2021-01-01       BROOKLYN          72
# 2 2021-01-01      MANHATTAN          23
# 3 2021-01-01         QUEENS          44
# 4 2021-01-01  STATEN ISLAND           8

# %%
from datetime import datetime
from datetime import date

app = Dash(__name__)


app.layout = html.Div([
    dcc.DatePickerSingle(
        id="date picker",
        min_date_allowed=collisions["DATE"].min(),
        max_date_allowed=collisions["DATE"].max(),
        initial_visible_month=collisions["DATE"].max(),
        date=collisions["DATE"].max(),
        display_format="YY-MMM-Do"
    ),
    dcc.Graph(id="graph")
])

@app.callback(Output("graph", "figure"), 
              [Input("date picker", "date")])
def plot_collisions_bar(date):
    fig = px.bar(
        collisions.loc[collisions["DATE"].eq(date)],
        x="COLLISIONS",
        y="BOROUGH",
        title=f"Traffic Accidents in NYC on {date}"
    )
    return fig

if __name__ == "__main__":
    app.run(mode="inline", port=8001, width="60%")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from datetime import datetime
from datetime import date

app = Dash(__name__)


app.layout = html.Div([
    dcc.DatePickerRange(
        id="date picker",
        min_date_allowed=collisions["DATE"].min(),
        max_date_allowed=collisions["DATE"].max(),
        initial_visible_month=collisions["DATE"].max(),
        start_date=collisions["DATE"].min(),
        end_date=date(2022,1,1),
        # display_format="YY-MMM-Do"
    ),
    dcc.Graph(id="graph")
])

@app.callback(Output("graph", "figure"), 
              [Input("date picker", "start_date"),
               Input("date picker", "end_date"),])
def plot_collisions_bar(start_date, end_date):
    fig = px.bar(
        (collisions
         .loc[collisions["DATE"].between(start_date, end_date)]
         .groupby("BOROUGH", as_index=False)
         .agg({"COLLISIONS": "sum"})
        )
        ,
        x="COLLISIONS",
        y="BOROUGH",
        title=f"Traffic Accidents in NYC between {start_date[:10]} and {end_date[:10]}"
    )
    return fig

if __name__ == "__main__":
    app.run(mode="inline", port=8001, width="60%")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Multiple Input Callbacks
# multiple inputs and outputs

# %%
app = Dash(__name__)

app.layout = html.Div([
    dcc.Dropdown(
        id="X Column Picker", 
        options=list(education.select_dtypes(include='number').columns),
        value="expenditure_per_student"
),
    dcc.Dropdown(
        id="Y Column Picker", 
        options=list(education.select_dtypes(include='number').columns),
        value="TOTAL_EXPENDITURE"
),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output('graph', 'figure'),
    Input("X Column Picker", "value"),
    Input("Y Column Picker", "value")
)

def plot_rev_scatter(x, y):
    if not x:
        raise PreventUpdate
    if not y:
        raise PreventUpdate
    fig = px.scatter(
        education, 
        x=x, 
        y=y,
        trendline="ols",
#         marginal_x="box",
#         marginal_y="box",
#         color="STATE", # can be continous
#         size="YEAR", # can't be missing
        title = "State Vs. Federal Revenue",
        )
    #fig.update_traces(marker_color=cstolor)
    return fig


if __name__ == "__main__":
    app.run(mode="inline", 
                   height=600, 
                   width="80%", 
                   debug=True,
                   port=6165
                  )
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:6165/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from datetime import datetime
from datetime import date

app = JupyterDash(__name__)


app.layout = html.Div([
    dcc.DatePickerRange(
        id="date picker",
        min_date_allowed=collisions["DATE"].min(),
        max_date_allowed=collisions["DATE"].max(),
        initial_visible_month=collisions["DATE"].max(),
        start_date=collisions["DATE"].min(),
        end_date=date(2022,1,1),
#         display_format="YY-MMM-Do"
),
    dcc.RadioItems(
        id="metric radio",
        options=["sum", "mean", "median", "min", "max"],
        value="sum"
),
    dcc.Dropdown(
        id="color dropdown",
        options=["red", "green", "blue"],
        value="blue"
),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output("graph", "figure"), 
    [Input("date picker", "start_date"), Input("date picker", "end_date")],
    Input("metric radio", "value"),
    Input("color dropdown", "value"),
)
def plot_collisions_bar(start_date, end_date, metric, color): 
    
    df = collisions.loc[collisions["DATE"].between(start_date, end_date)]
    
    fig = px.bar(
        (df
         .groupby("BOROUGH", as_index=False)
         .agg({"COLLISIONS": metric})
        )
        ,
        x="COLLISIONS",
        y="BOROUGH",
        title=f"Traffic Accidents in NYC between {start_date[:10]} and {end_date[:10]}"
    ).update_traces(marker_color=color)
    
    
    return fig

if __name__ == "__main__":
    app.run_server(mode="inline", port=8001)

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    html.H2(id="header"),
    dcc.Dropdown(
        id="X Column Picker",
        options=list(education.select_dtypes(include='number').columns),
        value="expenditure_per_student"
),
    dcc.Dropdown(
        id="Y Column Picker",
        options=list(education.select_dtypes(include='number').columns),
        value="TOTAL_EXPENDITURE"
),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output('header', 'children'),
    Output('graph', 'figure'),
    Input("X Column Picker", "value"),
    Input("Y Column Picker", "value")
)

def plot_rev_scatter(x, y):
    if not x:
        raise PreventUpdate
    if not y:
        raise PreventUpdate
    fig = px.scatter(
        education, 
        x=x, 
        y=y,
        trendline="ols",
    )
    
    header = f"{x.title().replace('_', ' ')} Vs. {y.title().replace('_', ' ')}"
    return header, fig

if __name__ == "__main__":
    app.run_server(mode="inline", debug=True, port=2039)

# %%
from datetime import datetime
from datetime import date

app = Dash(__name__)


app.layout = html.Div([
    dcc.DatePickerRange(
        id="date picker",
        min_date_allowed=collisions["DATE"].min(),
        max_date_allowed=collisions["DATE"].max(),
        initial_visible_month=collisions["DATE"].max(),
        start_date=collisions["DATE"].min(),
        end_date=date(2022,1,1),
#         display_format="YY-MMM-Do"
),
    dcc.RadioItems(
        id="metric radio",
        options=["sum", "mean", "median", "min", "max"],
        value="sum"
),
    dcc.Dropdown(
        id="color dropdown",
        options=["red", "green", "blue"],
        value="blue"
),
    dcc.Graph(id="graph"),
    dcc.Graph(id="graph2")
])

@app.callback(
    Output("graph", "figure"), #first output
    Output("graph2", "figure"), #second output
    [Input("date picker", "start_date"), Input("date picker", "end_date")], # first input
    Input("metric radio", "value"), # second input
    Input("color dropdown", "value"), # third input
)
def plot_collisions_bar(start_date, end_date, metric, color): 
    
    df = collisions.loc[collisions["DATE"].between(start_date, end_date)]
    
    fig = px.bar(
        (df
         .groupby("BOROUGH", as_index=False)
         .agg({"COLLISIONS": metric})
        )
        ,
        x="COLLISIONS",
        y="BOROUGH",
        title=f"Traffic Accidents in NYC between {start_date[:10]} and {end_date[:10]}"
    ).update_traces(marker_color=color)
    
    fig2 = px.line(
        df,
        x="DATE",
        y="COLLISIONS",
        color="BOROUGH"
    )
    
    return fig , fig2

if __name__ == "__main__":
    app.run(mode="inline", port=8001)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
